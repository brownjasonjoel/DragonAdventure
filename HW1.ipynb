# %% [markdown]
# <a href="https://colab.research.google.com/github/brownjasonjoel/DragonAdventure/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table of Contents <span class="tocSkip"></span>
# <div class="toc">
#   <ul class="toc-item">
#     <li> <a href="#Question1"> Q1(pts25)</a></li>
#     <li> <a href="#Question2"> Q2(pts25)</a></li>
#     <li> <a href="#Question1"> Q3(pts25)</a></li>
#     <li> <a href="#Question2"> Q4(pts25)</a></li>
#     </ul>
#     </div>

# %% [markdown]
# #Q1(pts25)
# <a name="Q1(pts25)"></a>
#
# Write a Python program that prints (displays) your name, your university, your major.
# Please note that you should print your output.

# %%
#please write your program
print ("Jason Brown")
print ("Texas A&M University - Victoria")
print ("Digital Gaming and Simulation")
# Out:
# Jason Brown
# Texas A&M University - Victoria
# Digital Gaming and Simulation

# %% [markdown]
# #Q2(pts25)
# <a name="Q1(pts25)"></a>
#
# Write a program to compute the area of a triangle. using the formula "0.5 * base * height" to compute the area. Please note that you should print your output.

# %%
#please write your program
base = float(input("Enter the Base: "))
height = float(input("Enter the height: "))
print(0.5 * base * height)
# Out:
# Enter the Base: 15.2
# Enter the height: 9.7
# 73.71999999999998

# %% [markdown]
# #Q3(pts25)
# <a name="Q3(pts25)"></a>
#
# Write and test a program to compute the area of a circle. This program should request a number representing a radius as input from the user. It should use the formula
# "3.14 * radius ** 2"
# to compute the area and then output this result suitably labeled.

# %%
#please write your program
radius = float(input("Enter the Radius"))
print(3.14 * radius ** 2 )
# Out:
# Enter the Radius5
# 78.5

# %% [markdown]
# #Q4(pts25)
# <a name="Q4(pts25)"></a>
#
# Consider the following interaction in the Python shell.
#
# #>>> first = input("Enter the first integer: ")
# #Enter the first number: 23
# #>>> second = input("Enter the second integer: ")
# #Enter the second number: 44
# #>>> print("The sum is", first + second)
# #The sum of the two integers is 2344
#
#
#
# The expected output is 67, but the output of this computation is 2344. Explain what causes this error and describe how to correct it.

# %%
# Answer
#the input were taken in as Strings not as Integers. to fix that problem you need to add the int() operation and then include the input into it.
#fixed the example:
first = int (input("Enter the first integer: "))

second = int(input("Enter the second integer: "))

print("The sum is", first + second)
# Out:
# Enter the first integer: 23
# Enter the second integer: 44
# The sum is 67
